# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Data loading

# %%
import pandas as pd

path = './artifacts/saved_df.csv'
df = pd.read_csv(path, index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3167 entries, 0 to 3166
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   type                 3167 non-null   object
#  1   date                 3167 non-null   object
#  2   time                 3167 non-null   object
#  3   duration             3167 non-null   object
#  4   distance             3167 non-null   object
#  5   origin               3167 non-null   object
#  6   destination          3167 non-null   object
#  7   total_earning        3167 non-null   float64
#  8   base_fare            3167 non-null   float64
#  9   customer_fare        3167 non-null   float64
#  10  paid_to_driver       3167 non-null   float64
#  11  paid_to_uber         3167 non-null   float64
#  12  datetime             3167 non-null   object
#  13  duration_dt          3167 non-null   object
#  14  distance_km          3167 non-null   float64
#  15  origin_lat_lng       3167 non-null   object
#  16  destination_lat_lng  3166 non-null   object
# dtypes: float64(6), object(11)
# memory usage: 445.4+ KB

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['duration_dt'] = pd.to_timedelta(df['duration_dt'])

# %% [markdown]
# ## Data exploration

# %%
df.head().T
# Out:
#                                                                      0  \
# type                                                             UberX
# date                                                        2023-11-11
# time                                                          17:28:00
# duration                                                 11 min 32 sec
# distance                                                       4.15 km
# origin               Rua Antônio das Chagas, Santo Amaro - São Paul...
# destination          R. Geórgia, Brooklin - São Paulo - SP, 04559-0...
# total_earning                                                    15.01
# base_fare                                                        11.01
# customer_fare                                                    19.97
# paid_to_driver                                                  -15.01
# paid_to_uber                                                      4.96
# datetime                                           2023-11-11 17:28:00
# duration_dt                                            0 days 00:11:32
# distance_km                                                       4.15
# origin_lat_lng                              [-23.6310457, -46.7009751]
# destination_lat_lng                         [-23.6108945, -46.6774821]
#
#                                                                      1  \
# type                                                             UberX
# date                                                        2023-11-11
# time                                                          17:20:00
# duration                                                         0 sec
# distance                                                           ---
# origin               Rua Luís Correia de Melo, Santo Amaro - São Pa...
# destination          Rua Luís Correia de Melo, Santo Amaro - São Pa...
# total_earning                                                     4.22
# base_fare                                                         4.22
# customer_fare                                                     5.25
# paid_to_driver                                                   -4.22
# paid_to_uber                                                      1.03
# datetime                                           2023-11-11 17:20:00
# duration_dt                                            0 days 00:00:00
# distance_km                                                        0.0
# origin_lat_lng                              [-23.6333821, -46.7150474]
# destination_lat_lng                         [-23.6333821, -46.7150474]
#
#                                                                      2  \
# type                                                             UberX
# date                                                        2023-11-11
# time                                                          16:37:00
# duration                                                 27 min 43 sec
# distance                                                      13.42 km
# origin               Rua Helena, Itaim Bibi - São Paulo - SP, 04552...
# destination          Rua Quipa, Campo Limpo - São Paulo - SP, 05756...
# total_earning                                                    27.09
# base_fare                                                        27.09
# customer_fare                                                    34.95
# paid_to_driver                                                  -27.09
# paid_to_uber                                                      7.86
# datetime                                           2023-11-11 16:37:00
# duration_dt                                            0 days 00:27:43
# distance_km                                                      13.42
# origin_lat_lng                               [-23.5930876, -46.685821]
# destination_lat_lng                          [-23.6232428, -46.757671]
#
#                                                                      3  \
# type                                                             UberX
# date                                                        2023-11-11
# time                                                          16:19:00
# duration                                                 16 min 18 sec
# distance                                                       4.78 km
# origin               Alameda Gabriel Monteiro da Silva, Jardim Amer...
# destination          Rua Helena, Itaim Bibi - São Paulo - SP, 04552...
# total_earning                                                    13.78
# base_fare                                                        13.78
# customer_fare                                                    22.96
# paid_to_driver                                                  -13.78
# paid_to_uber                                                      9.18
# datetime                                           2023-11-11 16:19:00
# duration_dt                                            0 days 00:16:18
# distance_km                                                       4.78
# origin_lat_lng                              [-23.5670517, -46.6779432]
# destination_lat_lng                          [-23.5930876, -46.685821]
#
#                                                                      4
# type                                                             UberX
# date                                                        2023-11-11
# time                                                          15:57:00
# duration                                                  5 min 29 sec
# distance                                                       1.38 km
# origin               R. Turiassu, Perdizes - São Paulo - SP, 05005-...
# destination          Rua Ministro Godói, Perdizes - São Paulo - SP,...
# total_earning                                                     6.69
# base_fare                                                         6.69
# customer_fare                                                    10.96
# paid_to_driver                                                   -6.69
# paid_to_uber                                                      4.27
# datetime                                           2023-11-11 15:57:00
# duration_dt                                            0 days 00:05:29
# distance_km                                                       1.38
# origin_lat_lng                               [-23.532765, -46.6705077]
# destination_lat_lng                         [-23.5411086, -46.6745064]

# %%
df['paid_to_driver'] = -1 * df['paid_to_driver']

# %%
df.describe()
# Out:
#        total_earning    base_fare  customer_fare  paid_to_driver  \
# count    3167.000000  3167.000000    3167.000000     3167.000000
# mean       23.649678    22.317540      34.445595       24.281964
# min       -10.820000     1.890000      -5.070000        1.890000
# 25%        12.450000    11.625000      19.340000       12.945000
# 50%        18.920000    17.580000      28.270000       19.760000
# 75%        29.410000    27.575000      43.140000       30.335000
# max       203.470000   203.470000     374.870000      209.470000
# std        16.639526    16.265912      23.131384       16.913488
#
#        paid_to_uber                       datetime                duration_dt  \
# count   3167.000000                           3167                       3167
# mean       9.433423  2024-04-29 13:43:56.703505152  0 days 00:18:37.175244711
# min      -42.080000            2023-11-06 20:41:00            0 days 00:00:00
# 25%        4.880000            2024-01-13 19:31:30     0 days 00:08:25.500000
# 50%        7.980000            2024-04-16 15:31:00            0 days 00:14:25
# 75%       12.640000            2024-08-13 19:12:00            0 days 00:24:09
# max      123.400000            2024-11-30 19:16:00            0 days 02:11:00
# std        8.456055                            NaN  0 days 00:14:58.348358803
#
#        distance_km
# count  3167.000000
# mean      6.400751
# min       0.000000
# 25%       2.270000
# 50%       4.140000
# 75%       7.955000
# max     110.550000
# std       7.117789

# %%
df[df['total_earning'] < 0]
# Out:
#        type        date      time      duration distance  \
# 83  Comfort  2023-11-18  20:26:00  3 min 41 sec  0.74 km
#
#                                                origin  \
# 83  Avenida Paulista, São Paulo - São Paulo - SP, ...
#
#                                           destination  total_earning  \
# 83  Rua Haddock Lobo, Cerqueira César - São Paulo ...         -10.82
#
#     base_fare  customer_fare  paid_to_driver  paid_to_uber  \
# 83       7.87          -5.07            9.18          5.75
#
#               datetime     duration_dt  distance_km  \
# 83 2023-11-18 20:26:00 0 days 00:03:41         0.74
#
#                 origin_lat_lng         destination_lat_lng
# 83  [-23.5573402, -46.6612825]  [-23.5579545, -46.6617369]

# %%
df[df['customer_fare'] < 0]
# Out:
#        type        date      time      duration distance  \
# 83  Comfort  2023-11-18  20:26:00  3 min 41 sec  0.74 km
#
#                                                origin  \
# 83  Avenida Paulista, São Paulo - São Paulo - SP, ...
#
#                                           destination  total_earning  \
# 83  Rua Haddock Lobo, Cerqueira César - São Paulo ...         -10.82
#
#     base_fare  customer_fare  paid_to_driver  paid_to_uber  \
# 83       7.87          -5.07            9.18          5.75
#
#               datetime     duration_dt  distance_km  \
# 83 2023-11-18 20:26:00 0 days 00:03:41         0.74
#
#                 origin_lat_lng         destination_lat_lng
# 83  [-23.5573402, -46.6612825]  [-23.5579545, -46.6617369]

# %%
df.drop(df[df['total_earning'] < 0].index, inplace=True)

# %%
df[df['total_earning'] < 0]
# Out:
# Empty DataFrame
# Columns: [type, date, time, duration, distance, origin, destination, total_earning, base_fare, customer_fare, paid_to_driver, paid_to_uber, datetime, duration_dt, distance_km, origin_lat_lng, destination_lat_lng]
# Index: []

# %%
df[df['paid_to_uber'] < 0]
# Out:
#          type        date      time       duration  distance  \
# 7       UberX  2023-11-11  12:32:00  21 min 33 sec   5.28 km
# 32      UberX  2023-11-09  19:33:00   9 min 51 sec   2.42 km
# 51      UberX  2023-11-08  07:29:00     1 hr 5 min  15.86 km
# 74      UberX  2023-11-19  01:36:00   8 min 11 sec   4.22 km
# 117     UberX  2023-11-15  21:19:00  21 min 31 sec  13.88 km
# ...       ...         ...       ...            ...       ...
# 3076    Black  2024-11-21  09:38:00  24 min 12 sec   8.58 km
# 3096  Comfort  2024-11-18  19:25:00  55 min 39 sec  23.04 km
# 3108      VIP  2024-11-30  18:32:00   18 min 4 sec   6.41 km
# 3116    Black  2024-11-29  18:57:00  13 min 25 sec   2.81 km
# 3165    Black  2024-11-25  07:48:00   7 min 42 sec   1.35 km
#
#                                                  origin  \
# 7     Rua Capital Federal, Perdizes - São Paulo - SP...
# 32       Rua Roma, Lapa - São Paulo - SP, 05050-090, BR
# 51    Avenida Doutor Salomão Vasconcelos, Cangaiba -...
# 74    Rua Maria Amália Lopes Azevedo, Tremembé - São...
# 117   Rua Calciolândia, Vila Medeiros - São Paulo - ...
# ...                                                 ...
# 3076  Rua Califórnia, Itaim Bibi - São Paulo - SP, 0...
# 3096  Rua Pedroso Alvarenga, Itaim Bibi - São Paulo ...
# 3108  Avenida Doutor Altino Arantes, Saúde - Sao Pau...
# 3116  Alameda Tietê, Jardim Paulista - Sao Paulo - S...
# 3165  Rua Lisboa, Jardim Paulista - São Paulo - SP, ...
#
#                                             destination  total_earning  \
# 7     Av. Rebouças, Bairro Pinheiros - São Paulo - S...          20.00
# 32    Rua Bica de Pedra, Perdizes - São Paulo - SP, ...          12.02
# 51    Rua Florêncio de Abreu, Sé - São Paulo - SP, 0...          40.06
# 74    Rua Albertina V da Silva Gordo, Mandaqui - São...          16.00
# 117   R. Pedro de Castillo, Furnas - São Paulo - SP,...          30.01
# ...                                                 ...            ...
# 3076  Avenida Brigadeiro Faria Lima, Pinheiros - São...          33.99
# 3096  Rua Domiciano Rossi, Centro - São Bernardo do ...          63.54
# 3108  Rua Xavier Curado, Ipiranga - Sao Paulo - SP, ...          23.53
# 3116  Rua Fradique Coutinho, Pinheiros - Sao Paulo -...          22.10
# 3165  Av. Brasil, Jardins - São Paulo - SP, 01431-01...          16.82
#
#       base_fare  customer_fare  paid_to_driver  paid_to_uber  \
# 7         20.00          24.88           20.00         -1.34
# 32        11.02          13.37           12.02         -1.07
# 51        38.81          42.88           40.06         -5.13
# 74        13.50          17.59           16.00         -1.10
# 117       30.01          32.21           30.01         -5.11
# ...         ...            ...             ...           ...
# 3076      33.99          38.05           33.99         -1.88
# 3096      60.54          70.35           63.54         -0.21
# 3108      20.53          27.53           23.53         -0.13
# 3116      17.21          25.86           22.10         -1.41
# 3165      10.32          22.13           19.70         -2.94
#
#                 datetime     duration_dt  distance_km  \
# 7    2023-11-11 12:32:00 0 days 00:21:33         5.28
# 32   2023-11-09 19:33:00 0 days 00:09:51         2.42
# 51   2023-11-08 07:29:00 0 days 01:05:00        15.86
# 74   2023-11-19 01:36:00 0 days 00:08:11         4.22
# 117  2023-11-15 21:19:00 0 days 00:21:31        13.88
# ...                  ...             ...          ...
# 3076 2024-11-21 09:38:00 0 days 00:24:12         8.58
# 3096 2024-11-18 19:25:00 0 days 00:55:39        23.04
# 3108 2024-11-30 18:32:00 0 days 00:18:04         6.41
# 3116 2024-11-29 18:57:00 0 days 00:13:25         2.81
# 3165 2024-11-25 07:48:00 0 days 00:07:42         1.35
#
#                   origin_lat_lng         destination_lat_lng
# 7     [-23.5407904, -46.6851003]   [-23.5645767, -46.678679]
# 32    [-23.5227259, -46.7017216]  [-23.5398646, -46.6965347]
# 51      [-23.504126, -46.524001]   [-23.539276, -46.6329022]
# 74    [-23.4564712, -46.5939624]   [-23.475604, -46.6236056]
# 117   [-23.4935981, -46.5817175]  [-23.4198084, -46.5814597]
# ...                          ...                         ...
# 3076  [-23.6143072, -46.6866123]  [-23.5687776, -46.6920303]
# 3096  [-23.5823143, -46.6803114]  [-23.6933196, -46.5624535]
# 3108  [-23.6026846, -46.6469652]   [-23.5844639, -46.604917]
# 3116  [-23.5611184, -46.6667842]  [-23.5645961, -46.6854736]
# 3165  [-23.5588991, -46.6801409]   [-23.5654723, -46.676687]
#
# [194 rows x 17 columns]

# %% [markdown]
# It seems that total_earning does not correspond to how much the driver earned. It's better to use paid_to_driver as total earning.

# %%
# Split df in paid rides and canceled ones.
df_paid_cancelations = df[df['distance_km']<= 0]
df_rides = df.drop(df_paid_cancelations.index)

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Formation of base benchmarks:
# - fee = paid_to_uber / customer_fare
# - earning_pct = paid_to_driver / customer_fare
# - earning_base_fare_pct = base_fare / customer_fare
# - traffic_benchmark = duration / distance
# - ted = paid_to_driver / duration
# - bfd = base_fare / duration
# - cfd = customer_fare / duration
# - pud = paid_to_uber / duration
# - tei = paid_to_driver / distance
# - bfi = base_fare / distance
# - cfi = customer_fare / distance
# - pui = paid_to_uber / distance
# - tedi = paid_to_driver / (duration * distance)
# - bfdi = base_fare / (duration * distance)
# - cfdi = customer_fare / (duration * distance)
# - pudi = paid_to_uber / (duration * distance)

# %%
df_rides['fee'] = df_rides['paid_to_uber'] / df_rides['customer_fare'] * 100
df_rides['earning_pct'] = df_rides['paid_to_driver'] / df_rides['customer_fare'] * 100
df_rides['earning_base_fare_pct'] = df_rides['base_fare'] / df_rides['customer_fare'] * 100
df_rides['traffic_benchmark'] = (df_rides['duration_dt'].dt.total_seconds()/60) / df_rides['distance_km']
df_rides['ted'] = df_rides['paid_to_driver'] / (df_rides['duration_dt'].dt.total_seconds()/60)
df_rides['bfd'] = df_rides['base_fare'] / (df_rides['duration_dt'].dt.total_seconds()/60)
df_rides['cfd'] = df_rides['customer_fare'] / (df_rides['duration_dt'].dt.total_seconds()/60)
df_rides['pud'] = df_rides['paid_to_uber'] / (df_rides['duration_dt'].dt.total_seconds()/60)
df_rides['tei'] = df_rides['paid_to_driver'] / df_rides['distance_km']
df_rides['bfi'] = df_rides['base_fare'] / df_rides['distance_km']
df_rides['cfi'] = df_rides['customer_fare'] / df_rides['distance_km']
df_rides['pui'] = df_rides['paid_to_uber'] / df_rides['distance_km']
df_rides['tedi'] = df_rides['paid_to_driver'] / ((df_rides['duration_dt'].dt.total_seconds()/60) * df_rides['distance_km'])
df_rides['bfdi'] = df_rides['base_fare'] / ((df_rides['duration_dt'].dt.total_seconds()/60) * df_rides['distance_km'])
df_rides['cfdi'] = df_rides['customer_fare'] / ((df_rides['duration_dt'].dt.total_seconds()/60) * df_rides['distance_km'])
df_rides['pudi'] = df_rides['paid_to_uber'] / ((df_rides['duration_dt'].dt.total_seconds()/60) * df_rides['distance_km'])

# %%
df_rides.T
# Out:
#                                                                     0     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            17:28:00
# duration                                                   11 min 32 sec
# distance                                                         4.15 km
# origin                 Rua Antônio das Chagas, Santo Amaro - São Paul...
# destination            R. Geórgia, Brooklin - São Paulo - SP, 04559-0...
# total_earning                                                      15.01
# base_fare                                                          11.01
# customer_fare                                                      19.97
# paid_to_driver                                                     15.01
# paid_to_uber                                                        4.96
# datetime                                             2023-11-11 17:28:00
# duration_dt                                              0 days 00:11:32
# distance_km                                                         4.15
# origin_lat_lng                                [-23.6310457, -46.7009751]
# destination_lat_lng                           [-23.6108945, -46.6774821]
# fee                                                            24.837256
# earning_pct                                                    75.162744
# earning_base_fare_pct                                          55.132699
# traffic_benchmark                                               2.779116
# ted                                                             1.301445
# bfd                                                             0.954624
# cfd                                                             1.731503
# pud                                                             0.430058
# tei                                                             3.616867
# bfi                                                             2.653012
# cfi                                                             4.812048
# pui                                                             1.195181
# tedi                                                            0.313601
# bfdi                                                             0.23003
# cfdi                                                             0.41723
# pudi                                                            0.103628
#
#                                                                     2     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            16:37:00
# duration                                                   27 min 43 sec
# distance                                                        13.42 km
# origin                 Rua Helena, Itaim Bibi - São Paulo - SP, 04552...
# destination            Rua Quipa, Campo Limpo - São Paulo - SP, 05756...
# total_earning                                                      27.09
# base_fare                                                          27.09
# customer_fare                                                      34.95
# paid_to_driver                                                     27.09
# paid_to_uber                                                        7.86
# datetime                                             2023-11-11 16:37:00
# duration_dt                                              0 days 00:27:43
# distance_km                                                        13.42
# origin_lat_lng                                 [-23.5930876, -46.685821]
# destination_lat_lng                            [-23.6232428, -46.757671]
# fee                                                             22.48927
# earning_pct                                                     77.51073
# earning_base_fare_pct                                           77.51073
# traffic_benchmark                                               2.065325
# ted                                                              0.97739
# bfd                                                              0.97739
# cfd                                                             1.260974
# pud                                                             0.283584
# tei                                                             2.018629
# bfi                                                             2.018629
# cfi                                                             2.604322
# pui                                                             0.585693
# tedi                                                            0.072831
# bfdi                                                            0.072831
# cfdi                                                            0.093962
# pudi                                                            0.021131
#
#                                                                     3     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            16:19:00
# duration                                                   16 min 18 sec
# distance                                                         4.78 km
# origin                 Alameda Gabriel Monteiro da Silva, Jardim Amer...
# destination            Rua Helena, Itaim Bibi - São Paulo - SP, 04552...
# total_earning                                                      13.78
# base_fare                                                          13.78
# customer_fare                                                      22.96
# paid_to_driver                                                     13.78
# paid_to_uber                                                        9.18
# datetime                                             2023-11-11 16:19:00
# duration_dt                                              0 days 00:16:18
# distance_km                                                         4.78
# origin_lat_lng                                [-23.5670517, -46.6779432]
# destination_lat_lng                            [-23.5930876, -46.685821]
# fee                                                            39.982578
# earning_pct                                                    60.017422
# earning_base_fare_pct                                          60.017422
# traffic_benchmark                                               3.410042
# ted                                                             0.845399
# bfd                                                             0.845399
# cfd                                                             1.408589
# pud                                                              0.56319
# tei                                                             2.882845
# bfi                                                             2.882845
# cfi                                                             4.803347
# pui                                                             1.920502
# tedi                                                            0.176862
# bfdi                                                            0.176862
# cfdi                                                            0.294684
# pudi                                                            0.117822
#
#                                                                     4     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            15:57:00
# duration                                                    5 min 29 sec
# distance                                                         1.38 km
# origin                 R. Turiassu, Perdizes - São Paulo - SP, 05005-...
# destination            Rua Ministro Godói, Perdizes - São Paulo - SP,...
# total_earning                                                       6.69
# base_fare                                                           6.69
# customer_fare                                                      10.96
# paid_to_driver                                                      6.69
# paid_to_uber                                                        4.27
# datetime                                             2023-11-11 15:57:00
# duration_dt                                              0 days 00:05:29
# distance_km                                                         1.38
# origin_lat_lng                                 [-23.532765, -46.6705077]
# destination_lat_lng                           [-23.5411086, -46.6745064]
# fee                                                            38.959854
# earning_pct                                                    61.040146
# earning_base_fare_pct                                          61.040146
# traffic_benchmark                                                3.97343
# ted                                                             1.220061
# bfd                                                             1.220061
# cfd                                                             1.998784
# pud                                                             0.778723
# tei                                                             4.847826
# bfi                                                             4.847826
# cfi                                                             7.942029
# pui                                                             3.094203
# tedi                                                            0.884102
# bfdi                                                            0.884102
# cfdi                                                            1.448394
# pudi                                                            0.564292
#
#                                                                     5     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            15:01:00
# duration                                                    2 min 54 sec
# distance                                                         0.96 km
# origin                 Rua das Tabocas, Alto de Pinheiros - São Paulo...
# destination            R. Delfina, Vila Madalena - São Paulo - SP, 05...
# total_earning                                                       6.11
# base_fare                                                           6.11
# customer_fare                                                       9.98
# paid_to_driver                                                      6.11
# paid_to_uber                                                        3.87
# datetime                                             2023-11-11 15:01:00
# duration_dt                                              0 days 00:02:54
# distance_km                                                         0.96
# origin_lat_lng                                [-23.5513208, -46.6977061]
# destination_lat_lng                           [-23.5539406, -46.6942296]
# fee                                                            38.777555
# earning_pct                                                    61.222445
# earning_base_fare_pct                                          61.222445
# traffic_benchmark                                               3.020833
# ted                                                             2.106897
# bfd                                                             2.106897
# cfd                                                             3.441379
# pud                                                             1.334483
# tei                                                             6.364583
# bfi                                                             6.364583
# cfi                                                            10.395833
# pui                                                              4.03125
# tedi                                                            2.194684
# bfdi                                                            2.194684
# cfdi                                                             3.58477
# pudi                                                            1.390086
#
#                                                                     6     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            13:06:00
# duration                                                     4 min 5 sec
# distance                                                         0.80 km
# origin                   Terminal Butantã, São Paulo - SP, 05510-050, BR
# destination            Avenida Afrânio Peixoto, Butantã - São Paulo -...
# total_earning                                                       9.52
# base_fare                                                           6.52
# customer_fare                                                       10.9
# paid_to_driver                                                      9.52
# paid_to_uber                                                        1.38
# datetime                                             2023-11-11 13:06:00
# duration_dt                                              0 days 00:04:05
# distance_km                                                          0.8
# origin_lat_lng                         [-23.5724349, -46.70984199999999]
# destination_lat_lng                           [-23.5659941, -46.7107432]
# fee                                                             12.66055
# earning_pct                                                     87.33945
# earning_base_fare_pct                                          59.816514
# traffic_benchmark                                               5.104167
# ted                                                             2.331429
# bfd                                                             1.596735
# cfd                                                             2.669388
# pud                                                             0.337959
# tei                                                                 11.9
# bfi                                                                 8.15
# cfi                                                               13.625
# pui                                                                1.725
# tedi                                                            2.914286
# bfdi                                                            1.995918
# cfdi                                                            3.336735
# pudi                                                            0.422449
#
#                                                                     7     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            12:32:00
# duration                                                   21 min 33 sec
# distance                                                         5.28 km
# origin                 Rua Capital Federal, Perdizes - São Paulo - SP...
# destination            Av. Rebouças, Bairro Pinheiros - São Paulo - S...
# total_earning                                                       20.0
# base_fare                                                           20.0
# customer_fare                                                      24.88
# paid_to_driver                                                      20.0
# paid_to_uber                                                       -1.34
# datetime                                             2023-11-11 12:32:00
# duration_dt                                              0 days 00:21:33
# distance_km                                                         5.28
# origin_lat_lng                                [-23.5407904, -46.6851003]
# destination_lat_lng                            [-23.5645767, -46.678679]
# fee                                                            -5.385852
# earning_pct                                                    80.385852
# earning_base_fare_pct                                          80.385852
# traffic_benchmark                                               4.081439
# ted                                                             0.928074
# bfd                                                             0.928074
# cfd                                                             1.154524
# pud                                                            -0.062181
# tei                                                             3.787879
# bfi                                                             3.787879
# cfi                                                             4.712121
# pui                                                            -0.253788
# tedi                                                            0.175772
# bfdi                                                            0.175772
# cfdi                                                             0.21866
# pudi                                                           -0.011777
#
#                                                                     8     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            12:28:00
# duration                                                    3 min 59 sec
# distance                                                         0.91 km
# origin                 R. Francisco Isoldi, Alto de Pinheiros - São P...
# destination            Rua Paulistânia, Sumarezinho - São Paulo - SP,...
# total_earning                                                        6.7
# base_fare                                                            6.7
# customer_fare                                                      10.97
# paid_to_driver                                                       6.7
# paid_to_uber                                                        4.27
# datetime                                             2023-11-11 12:28:00
# duration_dt                                              0 days 00:03:59
# distance_km                                                         0.91
# origin_lat_lng                                [-23.5465032, -46.6946018]
# destination_lat_lng                            [-23.547372, -46.6915299]
# fee                                                            38.924339
# earning_pct                                                    61.075661
# earning_base_fare_pct                                          61.075661
# traffic_benchmark                                               4.377289
# ted                                                             1.682008
# bfd                                                             1.682008
# cfd                                                             2.753975
# pud                                                             1.071967
# tei                                                             7.362637
# bfi                                                             7.362637
# cfi                                                            12.054945
# pui                                                             4.692308
# tedi                                                            1.848361
# bfdi                                                            1.848361
# cfdi                                                            3.026346
# pudi                                                            1.177985
#
#                                                                     9     \
# type                                                               UberX
# date                                                          2023-11-11
# time                                                            12:18:00
# duration                                                    1 min 54 sec
# distance                                                         0.55 km
# origin                 Rua Judite, Alto de Pinheiros - São Paulo - SP...
# destination            Rua Gumercindo Fleury, Alto de Pinheiros - São...
# total_earning                                                       6.11
# base_fare                                                           6.11
# customer_fare                                                       9.94
# paid_to_driver                                                      6.11
# paid_to_uber                                                        3.83
# datetime                                             2023-11-11 12:18:00
# duration_dt                                              0 days 00:01:54
# distance_km                                                         0.55
# origin_lat_lng                                [-23.5519551, -46.6968434]
# destination_lat_lng                           [-23.5484526, -46.6965608]
# fee                                                            38.531187
# earning_pct                                                    61.468813
# earning_base_fare_pct                                          61.468813
# traffic_benchmark                                               3.454545
# ted                                                             3.215789
# bfd                                                             3.215789
# cfd                                                             5.231579
# pud                                                             2.015789
# tei                                                            11.109091
# bfi                                                            11.109091
# cfi                                                            18.072727
# pui                                                             6.963636
# tedi                                                             5.84689
# bfdi                                                             5.84689
# cfdi                                                            9.511962
# pudi                                                            3.665072
#
#                                                                     10    ...  \
# type                                                               UberX  ...
# date                                                          2023-11-11  ...
# time                                                            12:10:00  ...
# duration                                                     4 min 0 sec  ...
# distance                                                         1.61 km  ...
# origin                 Av. Arruda Botelho, Alto de Pinheiros - São Pa...  ...
# destination            Pç. Panamericana, Alto de Pinheiros - São Paul...  ...
# total_earning                                                       6.89  ...
# base_fare                                                           6.89  ...
# customer_fare                                                      10.99  ...
# paid_to_driver                                                      6.89  ...
# paid_to_uber                                                         4.1  ...
# datetime                                             2023-11-11 12:10:00  ...
# duration_dt                                              0 days 00:04:00  ...
# distance_km                                                         1.61  ...
# origin_lat_lng                                [-23.5508975, -46.7178258]  ...
# destination_lat_lng                           [-23.5538417, -46.7088818]  ...
# fee                                                            37.306642  ...
# earning_pct                                                    62.693358  ...
# earning_base_fare_pct                                          62.693358  ...
# traffic_benchmark                                               2.484472  ...
# ted                                                               1.7225  ...
# bfd                                                               1.7225  ...
# cfd                                                               2.7475  ...
# pud                                                                1.025  ...
# tei                                                             4.279503  ...
# bfi                                                             4.279503  ...
# cfi                                                             6.826087  ...
# pui                                                             2.546584  ...
# tedi                                                            1.069876  ...
# bfdi                                                            1.069876  ...
# cfdi                                                            1.706522  ...
# pudi                                                            0.636646  ...
#
#                                                                     3157  \
# type                                                               UberX
# date                                                          2024-11-25
# time                                                            18:27:00
# duration                                                    27 min 0 sec
# distance                                                         8.12 km
# origin                 Rua Dona Ana Néri, Cambuci - São Paulo - SP, 0...
# destination            Rua Doutor Olavo Egídio, Santana - São Paulo -...
# total_earning                                                      27.52
# base_fare                                                          25.02
# customer_fare                                                       30.3
# paid_to_driver                                                     27.52
# paid_to_uber                                                        0.39
# datetime                                             2024-11-25 18:27:00
# duration_dt                                              0 days 00:27:00
# distance_km                                                         8.12
# origin_lat_lng                                 [-23.5566059, -46.614531]
# destination_lat_lng                           [-23.5000806, -46.6164575]
# fee                                                             1.287129
# earning_pct                                                    90.825083
# earning_base_fare_pct                                          82.574257
# traffic_benchmark                                               3.325123
# ted                                                             1.019259
# bfd                                                             0.926667
# cfd                                                             1.122222
# pud                                                             0.014444
# tei                                                             3.389163
# bfi                                                             3.081281
# cfi                                                             3.731527
# pui                                                              0.04803
# tedi                                                            0.125525
# bfdi                                                            0.114122
# cfdi                                                            0.138205
# pudi                                                            0.001779
#
#                                                                     3158  \
# type                                                               UberX
# date                                                          2024-11-25
# time                                                            17:05:00
# duration                                                     1 hr 20 min
# distance                                                        25.80 km
# origin                 Rua dos Têxteis, Cidade Tiradentes - São Paulo...
# destination            Rua Vitoantônio Del Vechio, Mooca - São Paulo ...
# total_earning                                                      54.96
# base_fare                                                          54.96
# customer_fare                                                      60.23
# paid_to_driver                                                     54.96
# paid_to_uber                                                        2.04
# datetime                                             2024-11-25 17:05:00
# duration_dt                                              0 days 01:20:00
# distance_km                                                         25.8
# origin_lat_lng                                 [-23.5860646, -46.407172]
# destination_lat_lng                            [-23.573697, -46.5916045]
# fee                                                             3.387016
# earning_pct                                                    91.250208
# earning_base_fare_pct                                          91.250208
# traffic_benchmark                                               3.100775
# ted                                                                0.687
# bfd                                                                0.687
# cfd                                                             0.752875
# pud                                                               0.0255
# tei                                                             2.130233
# bfi                                                             2.130233
# cfi                                                             2.334496
# pui                                                              0.07907
# tedi                                                            0.026628
# bfdi                                                            0.026628
# cfdi                                                            0.029181
# pudi                                                            0.000988
#
#                                                                     3159  \
# type                                                             Comfort
# date                                                          2024-11-25
# time                                                            16:00:00
# duration                                                   51 min 54 sec
# distance                                                        28.58 km
# origin                 Terminal 2, Aeroporto Internacional de São Pau...
# destination            Rua Ernesto Gould, Cidade Tiradentes - São Pau...
# total_earning                                                      76.38
# base_fare                                                          74.35
# customer_fare                                                      90.31
# paid_to_driver                                                     76.38
# paid_to_uber                                                        4.48
# datetime                                             2024-11-25 16:00:00
# duration_dt                                              0 days 00:51:54
# distance_km                                                        28.58
# origin_lat_lng                                [-23.4262553, -46.4816624]
# destination_lat_lng                           [-23.5879166, -46.4075586]
# fee                                                             4.960691
# earning_pct                                                    84.575352
# earning_base_fare_pct                                          82.327538
# traffic_benchmark                                               1.815955
# ted                                                             1.471676
# bfd                                                             1.432563
# cfd                                                             1.740077
# pud                                                              0.08632
# tei                                                             2.672498
# bfi                                                              2.60147
# cfi                                                             3.159902
# pui                                                             0.156753
# tedi                                                            0.051493
# bfdi                                                            0.050125
# cfdi                                                            0.060884
# pudi                                                             0.00302
#
#                                                                     3160  \
# type                                                             Comfort
# date                                                          2024-11-25
# time                                                            14:43:00
# duration                                                      1 hr 8 min
# distance                                                        29.37 km
# origin                 Rua Martim Francisco, Consolação - Sao Paulo -...
# destination            Terminal 3, Aeroporto Internacional de São Pau...
# total_earning                                                      76.52
# base_fare                                                          75.09
# customer_fare                                                     128.42
# paid_to_driver                                                     76.52
# paid_to_uber                                                       50.56
# datetime                                             2024-11-25 14:43:00
# duration_dt                                              0 days 01:08:00
# distance_km                                                        29.37
# origin_lat_lng                                [-23.5414758, -46.6545125]
# destination_lat_lng                    [-23.4302175, -46.47167109999999]
# fee                                                            39.370815
# earning_pct                                                    59.585734
# earning_base_fare_pct                                          58.472201
# traffic_benchmark                                               2.315288
# ted                                                             1.125294
# bfd                                                             1.104265
# cfd                                                             1.888529
# pud                                                             0.743529
# tei                                                              2.60538
# bfi                                                             2.556691
# cfi                                                             4.372489
# pui                                                             1.721485
# tedi                                                            0.038314
# bfdi                                                            0.037598
# cfdi                                                            0.064301
# pudi                                                            0.025316
#
#                                                                     3161  \
# type                                                             Comfort
# date                                                          2024-11-25
# time                                                            14:11:00
# duration                                                   25 min 27 sec
# distance                                                         8.19 km
# origin                 Rua Itaici, Santana - São Paulo - SP, 02460-03...
# destination            Rua Marquês de Itu, Consolação - São Paulo - S...
# total_earning                                                      26.02
# base_fare                                                          26.02
# customer_fare                                                      43.37
# paid_to_driver                                                     26.02
# paid_to_uber                                                       17.35
# datetime                                             2024-11-25 14:11:00
# duration_dt                                              0 days 00:25:27
# distance_km                                                         8.19
# origin_lat_lng                                [-23.4918831, -46.6369821]
# destination_lat_lng                           [-23.5436694, -46.6532661]
# fee                                                            40.004611
# earning_pct                                                    59.995389
# earning_base_fare_pct                                          59.995389
# traffic_benchmark                                               3.107448
# ted                                                             1.022397
# bfd                                                             1.022397
# cfd                                                             1.704126
# pud                                                             0.681729
# tei                                                             3.177045
# bfi                                                             3.177045
# cfi                                                             5.295482
# pui                                                             2.118437
# tedi                                                            0.124835
# bfdi                                                            0.124835
# cfdi                                                            0.208074
# pudi                                                            0.083239
#
#                                                                     3162  \
# type                                                               Black
# date                                                          2024-11-25
# time                                                            08:33:00
# duration                                                    4 min 48 sec
# distance                                                         1.23 km
# origin                 R. Fradique Coutinho, Pinheiros - São Paulo - ...
# destination            Rua Manuel Henrique Lopes, Pinheiros - São Pau...
# total_earning                                                      15.46
# base_fare                                                           9.96
# customer_fare                                                      18.49
# paid_to_driver                                                     15.46
# paid_to_uber                                                        3.03
# datetime                                             2024-11-25 08:33:00
# duration_dt                                              0 days 00:04:48
# distance_km                                                         1.23
# origin_lat_lng                                [-23.5577992, -46.6902498]
# destination_lat_lng                           [-23.5557853, -46.6957114]
# fee                                                            16.387236
# earning_pct                                                    83.612764
# earning_base_fare_pct                                          53.866955
# traffic_benchmark                                               3.902439
# ted                                                             3.220833
# bfd                                                                2.075
# cfd                                                             3.852083
# pud                                                              0.63125
# tei                                                            12.569106
# bfi                                                             8.097561
# cfi                                                             15.03252
# pui                                                             2.463415
# tedi                                                            2.618564
# bfdi                                                            1.686992
# cfdi                                                            3.131775
# pudi                                                            0.513211
#
#                                                                     3163  \
# type                                                               Black
# date                                                          2024-11-25
# time                                                            08:17:00
# duration                                                    7 min 49 sec
# distance                                                         1.10 km
# origin                 R. Fradique Coutinho, São Paulo - SP, 05422-00...
# destination            R. Mourato Coelho Sobreloja, Vila Madalena - S...
# total_earning                                                      13.76
# base_fare                                                           9.51
# customer_fare                                                      16.02
# paid_to_driver                                                     13.76
# paid_to_uber                                                        0.49
# datetime                                             2024-11-25 08:17:00
# duration_dt                                              0 days 00:07:49
# distance_km                                                          1.1
# origin_lat_lng                                 [-23.561063, -46.6879577]
# destination_lat_lng                            [-23.561251, -46.6891048]
# fee                                                             3.058677
# earning_pct                                                    85.892634
# earning_base_fare_pct                                          59.363296
# traffic_benchmark                                               7.106061
# ted                                                             1.760341
# bfd                                                             1.216631
# cfd                                                             2.049467
# pud                                                             0.062687
# tei                                                            12.509091
# bfi                                                             8.645455
# cfi                                                            14.563636
# pui                                                             0.445455
# tedi                                                             1.60031
# bfdi                                                            1.106028
# cfdi                                                            1.863152
# pudi                                                            0.056988
#
#                                                                     3164  \
# type                                                               Black
# date                                                          2024-11-25
# time                                                            08:03:00
# duration                                                    7 min 36 sec
# distance                                                         1.64 km
# origin                 Rua Francisco Leitão, Pinheiros - Sao Paulo - ...
# destination            R. Simão Álvares, Pinheiros - São Paulo - SP, ...
# total_earning                                                      15.53
# base_fare                                                          11.03
# customer_fare                                                      17.89
# paid_to_driver                                                     15.53
# paid_to_uber                                                        0.65
# datetime                                             2024-11-25 08:03:00
# duration_dt                                              0 days 00:07:36
# distance_km                                                         1.64
# origin_lat_lng                                [-23.5604935, -46.6817655]
# destination_lat_lng                           [-23.5633556, -46.6890644]
# fee                                                             3.633315
# earning_pct                                                    86.808273
# earning_base_fare_pct                                          61.654556
# traffic_benchmark                                               4.634146
# ted                                                             2.043421
# bfd                                                             1.451316
# cfd                                                             2.353947
# pud                                                             0.085526
# tei                                                             9.469512
# bfi                                                              6.72561
# cfi                                                            10.908537
# pui                                                             0.396341
# tedi                                                            1.245988
# bfdi                                                            0.884949
# cfdi                                                            1.435334
# pudi                                                             0.05215
#
#                                                                     3165  \
# type                                                               Black
# date                                                          2024-11-25
# time                                                            07:48:00
# duration                                                    7 min 42 sec
# distance                                                         1.35 km
# origin                 Rua Lisboa, Jardim Paulista - São Paulo - SP, ...
# destination            Av. Brasil, Jardins - São Paulo - SP, 01431-01...
# total_earning                                                      16.82
# base_fare                                                          10.32
# customer_fare                                                      22.13
# paid_to_driver                                                      19.7
# paid_to_uber                                                       -2.94
# datetime                                             2024-11-25 07:48:00
# duration_dt                                              0 days 00:07:42
# distance_km                                                         1.35
# origin_lat_lng                                [-23.5588991, -46.6801409]
# destination_lat_lng                            [-23.5654723, -46.676687]
# fee                                                           -13.285133
# earning_pct                                                    89.019431
# earning_base_fare_pct                                          46.633529
# traffic_benchmark                                               5.703704
# ted                                                             2.558442
# bfd                                                              1.34026
# cfd                                                             2.874026
# pud                                                            -0.381818
# tei                                                            14.592593
# bfi                                                             7.644444
# cfi                                                            16.392593
# pui                                                            -2.177778
# tedi                                                            1.895142
# bfdi                                                            0.992785
# cfdi                                                            2.128908
# pudi                                                           -0.282828
#
#                                                                     3166
# type                                                               Black
# date                                                          2024-11-25
# time                                                            06:49:00
# duration                                                   15 min 11 sec
# distance                                                         4.76 km
# origin                 Rua Alves Guimarães, Jardim Paulista - São Pau...
# destination            R. Dona Veridiana, Higienópolis - São Paulo - ...
# total_earning                                                      24.94
# base_fare                                                           20.3
# customer_fare                                                      33.75
# paid_to_driver                                                     28.73
# paid_to_uber                                                        5.02
# datetime                                             2024-11-25 06:49:00
# duration_dt                                              0 days 00:15:11
# distance_km                                                         4.76
# origin_lat_lng                                 [-23.558074, -46.6765949]
# destination_lat_lng                           [-23.5426737, -46.6512616]
# fee                                                            14.874074
# earning_pct                                                    85.125926
# earning_base_fare_pct                                          60.148148
# traffic_benchmark                                               3.189776
# ted                                                             1.892206
# bfd                                                             1.336992
# cfd                                                             2.222832
# pud                                                             0.330626
# tei                                                             6.035714
# bfi                                                             4.264706
# cfi                                                             7.090336
# pui                                                             1.054622
# tedi                                                            0.397522
# bfdi                                                            0.280881
# cfdi                                                            0.466982
# pudi                                                            0.069459
#
# [33 rows x 3106 columns]

# %%
# Some statistics of engineered features.
df_rides.iloc[:,-16:].describe().T
# Out:
#                         count       mean        std        min        25%  \
# fee                    3106.0  27.890808  14.827361 -85.273091  21.227895
# earning_pct            3106.0  70.028322  10.842473  32.239156  61.055754
# earning_base_fare_pct  3106.0  63.643565   9.462541  23.446659  59.974899
# traffic_benchmark      3106.0   3.587073   1.654064   0.805066   2.602176
# ted                    3106.0   1.536228   0.813015   0.433043   1.107823
# bfd                    3106.0   1.371537   0.584133   0.391726   1.035075
# cfd                    3106.0   2.211992   1.073666   0.636702   1.609723
# pud                    3106.0   0.625579   0.496719  -5.820000   0.366796
# tei                    3106.0   5.553911  10.546732   1.161911   3.498484
# bfi                    3106.0   4.910562   9.218860   1.161911   3.291346
# cfi                    3106.0   7.987433  15.241136   1.162530   5.109522
# pui                    3106.0   2.241028   5.441768 -80.833333   1.184682
# tedi                   3106.0   0.901777  10.815973   0.009636   0.153285
# bfdi                   3106.0   0.762306   9.116401   0.009629   0.144559
# cfdi                   3106.0   1.282015  15.243999   0.012690   0.221350
# pudi                   3106.0   0.316194   5.188805 -97.000000   0.046790
#
#                              50%        75%         max
# fee                    34.550489  38.794046   41.131956
# earning_pct            65.135683  77.064336  133.773165
# earning_base_fare_pct  61.765504  66.603208  133.773165
# traffic_benchmark       3.348431   4.287037   50.833333
# ted                     1.378844   1.723635   22.500000
# bfd                     1.270874   1.559897   11.400000
# cfd                     2.020268   2.531542   24.648000
# pud                     0.628633   0.860244    5.409836
# tei                     4.641873   6.172056  476.000000
# bfi                     4.324893   5.495495  476.000000
# cfi                     6.830881   9.027348  751.000000
# pui                     2.062138   2.962669  275.000000
# tedi                    0.312894   0.647013  468.196721
# bfdi                    0.287711   0.575781  468.196721
# cfdi                    0.461449   0.959870  738.688525
# pudi                    0.127282   0.282618  270.491803

# %% [markdown]
# With these features we can have a better understanding of the data and the relationships between the variables. Now, let's generate some visualizations to understand the data better.

# %%
df_rides.to_csv('./artifacts/df_rides.csv')
df_paid_cancelations.to_csv('./artifacts/df_paid_cancelations.csv')
